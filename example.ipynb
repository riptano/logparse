# %% [markdown]
# # Log Analysis Examples with pandas
#
# This notebook contains many useful examples of analysis that can be done on a log file once it has been parsed.  This includes graphing
# and histogramming garbage collections, compactions, flushes, and exception frequency, as well as querying version and environmental information.
#
# Refer to [Diving into Open Data with IPython Notebook & Pandas](http://nbviewer.ipython.org/github/jvns/talks/blob/master/pyconca2013/pistes-cyclables.ipynb) for a quick overview of using IPython and pandas together.  More information can be found on the [IPython](http://ipython.org/) and [pandas](http://pandas.pydata.org/) web pages.
#
# These are just some of the things you could do. IPython makes exploratory computing easy, so don't hesitate to try new things!
#
# To run a block, click on the code and press `Ctrl`+`Enter`.  You must do this for each individual block in order to refresh it after loading a new log.

# %% [markdown]
# ## Initialization
#
# **Important!** These two blocks must be run before you can do any of the examples below. Note that not every example will work with every log. It depends on what's in the log.
#
# - Block #1 imports all of the libraries and does any configuration necessary.
# - Block #2 parses the log file. There are 3 example log files included, so try them all. You can also use your own log file by passing its full path to the SystemLog constructor.

# %%
import pylab
import pandas as pd
import cassandra
import pprint
reload(cassandra)

pylab.rcParams['figure.figsize'] = 18, 12

# %%
logfiles = ['system0.log', 'system1.log', 'system2.log']

#0=Good general example
#1=Good compaction example
#2=Good GC Example

log = cassandra.SystemLog(logfiles[0])

# %% [markdown]
# ## Environment

# %%
log.sessions[1]['environment']['jvm']
# Out:
# 'Java HotSpot(TM) 64-Bit Server VM/1.7.0_21'

# %%
pd.DataFrame.from_records(log.sessions[1]['versions'], columns=['component','version'])
# Out:
#         component                       version
# 0             DSE                         3.1.3
# 1          Hadoop                       1.0.4.8
# 2            Hive                       0.9.0.1
# 3             Pig                         0.9.2
# 4            Solr                       4.3.0.1
# 5           Sqoop                       1.4.2.3
# 6          Mahout                           0.6
# 7        Appender                           1.1
# 8       Cassandra                       1.2.6.6
# 9      Thrift API                       19.36.0
# 10  CQL supported  2.0.0,3.0.4 (default: 3.0.4)

# %% [markdown]
# ## Garbage Collection

# %%
gc = pd.DataFrame.from_records(log.sessions[0]['garbage_collections'], 
                               columns=['date', 'collections', 'duration'], index='date')

hourly = gc.resample('H', how='sum').dropna()
hourly.plot(y='duration', logy=True)

# %%
gc['duration'].hist(bins=100)

# %%
pd.DataFrame.from_records(log.sessions[0]['heap_warnings'], index='date')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-4a5bf7b0f099> in <module>()
# ----> 1 pd.DataFrame.from_records(log.sessions[0]['heap_warnings'], index='date')
#
# KeyError: 'heap_warnings'

# %% [markdown]
# ## Compactions

# %%
compactions = pd.DataFrame.from_records(log.sessions[0]['compactions'],index='begin_date')
compactions.describe()
# Out:
#          duration     input_bytes    output_bytes  percent_of_original  \
# count    2.000000        2.000000        2.000000             2.000000
# mean    88.000000   562276.500000   579794.500000           100.500000
# std     57.982756   664051.756387   690814.333841             3.535534
# min     47.000000    92721.000000    91315.000000            98.000000
# 25%     67.500000   327498.750000   335554.750000            99.250000
# 50%     88.000000   562276.500000   579794.500000           100.500000
# 75%    108.500000   797054.250000   824034.250000           101.750000
# max    129.000000  1031832.000000  1068274.000000           103.000000
#
#            rate  sstable_count  total_rows  unique_rows
# count  2.000000              2    2.000000     2.000000
# mean   4.875215              2  303.000000   175.000000
# std    4.274245              0    5.656854     5.656854
# min    1.852867              2  299.000000   171.000000
# 25%    3.364041              2  301.000000   173.000000
# 50%    4.875215              2  303.000000   175.000000
# 75%    6.386388              2  305.000000   177.000000
# max    7.897562              2  307.000000   179.000000

# %%
compactions['rate'].resample('H', how='count').plot()

# %%
compactions['rate'].hist(bins=50)

# %% [markdown]
# ## Flushes

# %%
flushes = pd.DataFrame.from_records(log.sessions[0]['flushes'],index='begin_date')
flushes['filename'].resample('H', how='count').plot()

# %% [markdown]
# ## Errors

# %%
errors = pd.DataFrame.from_records(log.sessions[0]['errors'], index='date')
errors['exception'].value_counts().plot(kind='barh')

# %% [markdown]
# ## Repairs

# %%
ielist = []
for session in log.sessions[6]['repair_sessions']:
    ielist.extend(session.get('inconsistent_endpoints', []))
iedf = pd.DataFrame.from_records(ielist, index='date')
iedf.sort('ranges').tail(50)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-91f47b5c4c50> in <module>()
#       1 ielist = []
# ----> 2 for session in log.sessions[6]['repair_sessions']:
#       3     ielist.extend(session.get('inconsistent_endpoints', []))
#       4 iedf = pd.DataFrame.from_records(ielist, index='date')
#       5 iedf.sort('ranges').tail(50)
#
# IndexError: list index out of range

# %%
l = []
for session in log.sessions[6]['repair_sessions']:
    l.extend(session.get('merkle_requests', []))
df = pd.DataFrame.from_records(l, index='request_date')
df.tail(60)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-ca7661998c7d> in <module>()
#       1 l = []
# ----> 2 for session in log.sessions[6]['repair_sessions']:
#       3     l.extend(session.get('merkle_requests', []))
#       4 df = pd.DataFrame.from_records(l, index='request_date')
#       5 df.tail(60)
#
# IndexError: list index out of range

# %% [markdown]
# ## Unrecognized Messages
#
# The log parser isn't complete and probably will always be a work in progress. The goal is to parse the most useful messages first.  This report shows the number of unrecognized messages for each category/source file.  Generally when writing a new parser, I choose one of the categories at the top of the list.

# %%
unknown = pd.DataFrame.from_records(log.unknown_messages, index='date')
unknown.source_file.value_counts()
# Out:
# ShardRouter.java                        43971
# StatusLogger.java                       23682
# SolrException.java                       2320
# SecondaryIndexManager.java                644
# SolrCoreResourceManager.java              204
# AutoSavingCache.java                      136
# CommitLogReplayer.java                     64
# IndexWorker.java                           64
# Memtable.java                              62
# SolrSecondaryIndex.java                    42
# SSTableReader.java                         42
# ColumnFamilyStore.java                     38
# CassandraShowFileRequestHandler.java       37
# CachingDirectoryFactory.java               28
# TNegotiatingServerTransport.java           21
# CustomTThreadPoolServer.java               21
# CassandraDirectUpdateHandler2.java         18
# SolrDispatchFilter.java                    17
# IndexSchema.java                           16
# SolrResourceLoader.java                    12
# StorageService.java                         8
# DseSolrConfig.java                          8
# SolrConfig.java                             8
# DatabaseDescriptor.java                     7
# PluginManager.java                          6
# CoreContainer.java                          6
# OutboundTcpConnection.java                  6
# Gossiper.java                               5
# SolrCore.java                               5
# CacheService.java                           4
# XMLLoader.java                              4
# XSLTResponseWriter.java                     4
# JmxMonitoredMap.java                        4
# AuditLoggerPlugin.java                      3
# ThriftServer.java                           3
# SolrHttpAuditLogFilter.java                 2
# DseConfig.java                              2
# CassandraDaemon.java                        2
# SolrContainerPlugin.java                    2
# CommitLog.java                              2
# Server.java                                 2
# HttpClientUtil.java                         2
# EndpointStateTracker.java                   1
# DseDelegateSnitch.java                      1
# EndpointStatePersister.java                 1
# TServerCustomFactory.java                   1
# DseSimpleSnitch.java                        1
# DseDaemon.java                              1
# MigrationManager.java                       1
# CLibrary.java                               1
# MessagingService.java                       1
# Length: 51, dtype: int64
