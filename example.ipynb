# %% [markdown]
# # Log Analysis Examples with pandas
#
# This notebook contains many useful examples of analysis that can be done on a log file once it has been parsed.  This includes graphing
# and histogramming garbage collections, compactions, flushes, and exception frequency, as well as querying version and environmental information.
#
# Refer to [Diving into Open Data with IPython Notebook & Pandas](http://nbviewer.ipython.org/github/jvns/talks/blob/master/pyconca2013/pistes-cyclables.ipynb) for a quick overview of using IPython and pandas together.  More information can be found on the [IPython](http://ipython.org/) and [pandas](http://pandas.pydata.org/) web pages.
#
# These are just some of the things you could do. IPython makes exploratory computing easy, so don't hesitate to try new things!
#
# To run a block, click on the code and press `Ctrl`+`Enter`.  You must do this for each individual block in order to refresh it after loading a new log.

# %% [markdown]
# ## Initialization
#
# **Important!** These two blocks must be run before you can do any of the examples below. Note that not every example will work with every log. It depends on what's in the log.
#
# - Block #1 imports all of the libraries and does any configuration necessary.
# - Block #2 parses the log file. There are 3 example log files included, so try them all. You can also use your own log file by passing its full path to the SystemLog constructor.

# %%
import pylab
import pandas as pd
import cassandra
import pprint
reload(cassandra)

pylab.rcParams['figure.figsize'] = 18, 12

# %%
logfiles = ['system0.log', 'system1.log', 'system2.log']

#0=Good general example
#1=Good compaction example
#2=Good GC Example

log = cassandra.SystemLog(logfiles[0])

# %%
log.solr_index('http://localhost:8983/solr/systemlog.log')
# Out:
# ---------------------------------------------------------------------------
# SolrException                             Traceback (most recent call last)
# <ipython-input-39-96c50d32ec4f> in <module>()
# ----> 1 log.solr_index('http://localhost:8983/solr/systemlog.log')
#
# /Users/jblangston/repos/support_tool/logparse/cassandra.py in solr_index(self, url)
#      98                     line_fields['string_' + key] = str(value)
#      99             print line_fields
# --> 100             s.add(line_fields)
#     101
#     102
#
# /Library/Python/2.7/site-packages/solr/core.pyc in add(self, _commit, **fields)
#     676         This is equialent to ``solr.Solr.add(fields, commit=_commit)``.
#     677         """
# --> 678         return Solr.add_many(self, [fields], commit=_commit)
#     679
#     680     def add_many(self, docs, _commit=False):
#
# /Library/Python/2.7/site-packages/solr/core.pyc in wrapper(self, *args, **kw)
#     324         content = function(self, *args, **kw)
#     325         if content:
# --> 326             return self._update(content, query)
#     327         # If there's nothing to do (no content), should we issue a
#     328         # commit/optimize if those are requested by the options?
#
# /Library/Python/2.7/site-packages/solr/core.pyc in _update(self, request, query)
#     548         selector = '%s/update%s' % (self.path, qs_from_items(query))
#     549         try:
# --> 550             rsp = self._post(selector, request, self.xmlheaders)
#     551             data = rsp.read()
#     552         finally:
#
# /Library/Python/2.7/site-packages/solr/core.pyc in _post(self, url, body, headers)
#     637             try:
#     638                 self.conn.request('POST', url, body.encode('UTF-8'), _headers)
# --> 639                 return check_response_status(self.conn.getresponse())
#     640             except (socket.error,
#     641                     httplib.ImproperConnectionState,
#
# /Library/Python/2.7/site-packages/solr/core.pyc in check_response_status(response)
#    1100         except:
#    1101             pass
# -> 1102         raise ex
#    1103     return response
#    1104
#
# SolrException: HTTP code=500, reason=Internal Server Error
# {'string_node': '/10.65.16.170', 'string_session_id': 'c1fd8510-607e-11e3-bfcb-9b6dd34e330a', 'thread': 'Thread-116859', 'level': 'INFO', 'log_id': 'system0.log', 'source_lineno': '199', 'date': datetime.datetime(2013, 12, 8, 21, 5, 29, 314000), 'session': 0, 'log_lineno': 1, 'source_file': 'StreamInSession.java', 'message': 'Finished streaming session c1fd8510-607e-11e3-bfcb-9b6dd34e330a from /10.65.16.170', 'type': 'finished_streaming', 'date_end_date': datetime.datetime(2013, 12, 8, 21, 5, 29, 314000)}

# %% [markdown]
# ## Environment

# %%
log.sessions[1]['environment']['jvm']
# Out:
# 'Java HotSpot(TM) 64-Bit Server VM/1.6.0_45'

# %%
pd.DataFrame.from_records(log.sessions[1]['versions'], columns=['component','version'])
# Out:
#         component                       version
# 0             DSE                         3.1.4
# 1          Hadoop                       1.0.4.8
# 2            Hive                       0.9.0.1
# 3             Pig                         0.9.2
# 4            Solr                     4.3.0.1.2
# 5           Sqoop                       1.4.2.3
# 6          Mahout                           0.6
# 7        Appender                           1.1
# 8       Cassandra                      1.2.10.1
# 9      Thrift API                       19.36.0
# 10  CQL supported  2.0.0,3.0.5 (default: 3.0.5)

# %% [markdown]
# ## Garbage Collection

# %%
gc = pd.DataFrame.from_records(log.sessions[0]['garbage_collections'], 
                               columns=['date', 'collections', 'duration'], index='date')
#day=gc['20131012']
hourly = gc.resample('H', how='sum')
hourly.plot(y='duration', logy=False)

# %%
gc['duration'].hist(bins=100)

# %%
pd.DataFrame.from_records(log.sessions[0]['heap_warnings'], index='date')
# Out:
#                             percent_full
# date
# 2013-12-09 13:08:55.627000     76.689610
# 2013-12-09 13:41:21.460000     75.100506
# 2013-12-11 06:23:36.933000     79.067975
# 2013-12-11 06:32:28.680000     77.822177
# 2013-12-12 10:45:20.961000     77.121660
# 2013-12-12 10:55:32.734000     78.643009
# 2013-12-13 04:37:27.090000     78.402728
# 2013-12-13 10:14:58.529000     77.350257
# 2013-12-13 16:21:04.448000     75.932810
# 2013-12-13 16:26:36.765000     76.598674
# 2013-12-13 16:56:30.835000     78.355627
# 2013-12-13 19:33:05.745000     76.765837
# 2013-12-13 19:33:24.524000     78.957230

# %% [markdown]
# ## Compactions

# %%
compactions = pd.DataFrame.from_records(log.sessions[0]['compactions'],index='begin_date')
compactions.describe()
# Out:
#              duration   input_bytes  output_bytes  percent_of_original  \
# count     6894.000000  6.894000e+03  6.894000e+03          6894.000000
# mean     30627.632144  5.781562e+07  5.600845e+07           101.386713
# std     225414.699089  3.446969e+08  2.564950e+08             4.086171
# min          5.000000  6.250000e+02  2.660000e+02            39.000000
# 25%       7544.500000  1.570305e+07  1.594695e+07           100.000000
# 50%      12812.500000  2.960630e+07  3.011574e+07           101.000000
# 75%      18701.500000  4.491040e+07  4.575721e+07           102.000000
# max    9451183.000000  1.351363e+10  9.014415e+09           123.000000
#
#               rate  sstable_count     total_rows    unique_rows
# count  6894.000000    6894.000000    6894.000000    6894.000000
# mean      2.326579       3.997534     795.646359     722.663621
# std       0.683598       0.073224   12387.582495   12332.735111
# min       0.050735       2.000000       4.000000       1.000000
# 25%       2.181049       4.000000      94.000000      68.000000
# 50%       2.532223       4.000000     145.000000     107.000000
# 75%       2.706718       4.000000     189.000000     130.000000
# max      10.002235       5.000000  334676.000000  334629.000000

# %%
#compactions = compactions.dropna()
compactions['rate'].resample('H', how='count').plot()

# %%
compactions['rate'].hist(bins=50)

# %% [markdown]
# ## Flushes

# %%
flushes = pd.DataFrame.from_records(log.sessions[0]['flushes'], index='begin_date')
flushes['serialized_bytes'].resample('H', how='count').plot()
#flushes['queue_duration'] = flushes['begin_date'] - flushes['enqueue_date']
#flushes['flush_duration'] = flushes['end_date'] - flushes['begin_date']
#flushes.sort('flush_duration')
#flushes.tail()

# %% [markdown]
# ## Errors

# %%
errors = pd.DataFrame.from_records(log.sessions[0]['errors'], index='date')
errors['exception'].value_counts().plot(kind='barh')

# %% [markdown]
# ## Repairs

# %%
tmp = []
for session in log.sessions[6]['repair_sessions']:
    tmp.extend(session.get('inconsistent_endpoints', []))
inconsistent = pd.DataFrame.from_records(tmp, index='date')
inconsistent.sort(columns=['session_id', 'column_family', 'node1', 'node2']).tail(50)
# Out:
#                            column_family           node1           node2  \
# date
# 2014-01-03 15:39:27.126000     rollups60  /10.65.131.222  /10.65.131.221
# 2014-01-03 15:39:26.528000     rollups60  /10.65.131.222  /10.66.131.119
# 2014-01-03 15:39:28.361000     rollups60  /10.66.131.119  /10.65.131.221
# 2014-01-03 15:39:25.835000     rollups60   /10.66.131.46  /10.65.131.221
# 2014-01-03 15:39:24.928000     rollups60   /10.66.131.46  /10.65.131.222
# 2014-01-03 15:39:25.496000     rollups60   /10.66.131.46  /10.66.131.119
# 2014-01-03 15:39:25.535000   rollups7200  /10.65.131.222  /10.65.131.221
# 2014-01-03 15:39:25.462000   rollups7200  /10.65.131.222  /10.66.131.119
# 2014-01-03 15:39:25.636000   rollups7200  /10.66.131.119  /10.65.131.221
# 2014-01-03 15:39:25.396000   rollups7200   /10.66.131.46  /10.65.131.221
# 2014-01-03 15:39:25.252000   rollups7200   /10.66.131.46  /10.65.131.222
# 2014-01-03 15:39:25.364000   rollups7200   /10.66.131.46  /10.66.131.119
# 2014-01-03 15:39:21.675000  rollups86400  /10.65.131.222  /10.66.131.119
# 2014-01-03 15:39:21.729000  rollups86400  /10.66.131.119  /10.65.131.221
# 2014-01-03 15:39:21.626000  rollups86400   /10.66.131.46  /10.65.131.221
# 2014-01-03 15:39:21.561000  rollups86400   /10.66.131.46  /10.65.131.222
# 2014-01-03 15:39:21.594000  rollups86400   /10.66.131.46  /10.66.131.119
# 2014-01-03 11:50:38.899000        events  /10.65.131.222  /10.65.131.221
# 2014-01-03 11:50:38.875000        events  /10.65.131.222  /10.66.131.119
# 2014-01-03 11:50:38.847000        events   /10.66.131.46  /10.65.131.221
# 2014-01-03 11:50:38.801000        events   /10.66.131.46  /10.66.131.119
# 2014-01-03 16:45:23.456000        events  /10.65.131.222  /10.66.131.119
# 2014-01-03 16:45:23.478000        events  /10.66.131.119  /10.65.131.221
# 2014-01-03 16:45:23.428000        events   /10.66.131.46  /10.65.131.221
# 2014-01-03 16:45:23.354000        events   /10.66.131.46  /10.65.131.222
# 2014-01-03 16:45:23.406000        events   /10.66.131.46  /10.66.131.119
# 2014-01-03 16:45:22.687000    rollups300  /10.65.131.222  /10.65.131.221
      1  b9f4db80-74c8-11e3-978d-597868584bac
# 2014-01-03 16:45:21.485000      1  b9f4db80-74c8-11e3-978d-597868584bac
# 2014-01-03 16:45:21.515000      1  b9f4db80-74c8-11e3-978d-597868584bac

# %%
tmp = []
for session in log.sessions[6]['repair_sessions']:
    tmp.extend(session.get('merkle_requests', []))
merkle_requests = pd.DataFrame.from_records(tmp, index='request_date')
merkle_requests.tail(60)
# Out:
#                                           column_family            node  \
# request_date
# 2014-01-03 17:41:24.506000                 AuditHistory  /10.65.131.222
# 2014-01-03 17:41:24.887000      DepartmentThreshold_IDX   /10.66.131.46
# 2014-01-03 17:39:49.636000  ItemLocationEligibility_IDX  /10.65.131.221
# 2014-01-03 17:40:29.584000      ItemLocationEligibility   /10.66.131.46
# 2014-01-03 17:40:29.415000            ItemThreshold_IDX   /10.66.131.46
# 2014-01-03 17:41:24.355000          ItemEligibility_IDX   /10.66.131.46
# 2014-01-03 17:41:24.228000             FileLoadData_IDX  /10.65.131.221
# 2014-01-03 17:39:49.636000  ItemLocationEligibility_IDX   /10.66.131.46
# 2014-01-03 17:41:25.430000              ItemEligibility   /10.66.131.46
# 2014-01-03 17:40:29.415000            ItemThreshold_IDX  /10.65.131.221
# 2014-01-03 17:41:24.506000                 AuditHistory   /10.66.131.46
# 2014-01-03 17:41:25.143000                ItemThreshold   /10.66.131.46
# 2014-01-03 17:41:25.303000             AuditHistory_IDX  /10.66.131.119
# 2014-01-03 17:41:24.228000             FileLoadData_IDX   /10.66.131.46
# 2014-01-03 17:41:24.762000                 FileLoadData  /10.65.131.221
# 2014-01-03 17:41:25.303000             AuditHistory_IDX   /10.66.131.46
# 2014-01-03 17:41:24.506000                 AuditHistory  /10.65.131.221
# 2014-01-03 17:41:24.887000      DepartmentThreshold_IDX  /10.65.131.222
# 2014-01-03 17:40:29.281000          LocationEligibility  /10.65.131.222
# 2014-01-03 17:41:25.430000              ItemEligibility  /10.66.131.119
# 2014-01-03 17:41:24.355000          ItemEligibility_IDX  /10.66.131.119
# 2014-01-03 17:41:24.355000          ItemEligibility_IDX  /10.65.131.222
# 2014-01-03 17:41:24.228000             FileLoadData_IDX  /10.65.131.222
# 2014-01-03 17:41:25.604000            FeatureToggle_IDX   /10.66.131.46
# 2014-01-03 17:41:24.228000             FileLoadData_IDX  /10.66.131.119
# 2014-01-03 17:41:25.430000              ItemEligibility  /10.65.131.222
# 2014-01-03 17:41:24.762000                 FileLoadData  /10.66.131.119
# 2014-01-03 17:41:25.019000      LocationEligibility_IDX   /10.66.131.46
# 2014-01-03 17:40:29.281000          LocationEligibility   /10.66.131.46
# 2014-01-03 17:41:24.887000      DepartmentThreshold_IDX  /10.66.131.119
# 2014-01-03 17:41:24.632000          DepartmentThreshold  /10.65.131.221
# 2014-01-03 17:41:25.303000             AuditHistory_IDX  /10.65.131.222
# 2014-01-03 17:40:29.281000          LocationEligibility  /10.65.131.221
# 2014-01-03 17:41:24.632000          DepartmentThreshold   /10.66.131.46
# 2014-01-03 17:41:25.019000      LocationEligibility_IDX  /10.66.131.119
# 2014-01-03 17:41:25.143000                ItemThreshold  /10.66.131.119
# 2014-01-03 17:41:24.355000          ItemEligibility_IDX  /10.65.131.221
# 2014-01-03 17:41:25.604000            FeatureToggle_IDX  /10.66.131.119
# 2014-01-03 17:39:49.636000  ItemLocationEligibility_IDX  /10.66.131.119
# 2014-01-03 17:41:25.604000            FeatureToggle_IDX  /10.65.131.222
# MigrationStage              0                 0        0         54        0
# MemtablePostFlusher         0                 0        0      92040        0
# MemoryMeter                 0                 0        0        157        0
# FlushWriter                 0                25        0        398        0
# MiscStage                   0                 0        0       9668        0
# commitlog_archiver          0                 0        0          0        0
# InternalResponseStage       0                 0        0         11        0
# AntiEntropySessions         0                 0        0       1028        0
# HintedHandoff               0                 0        0         89        0

# %%
caches = pd.DataFrame.from_records(log.sessions[0]['status'][2]['caches'],index='type')
caches
# Out:
#            capacity keys_to_save                                           provider       size
# type
# KeyCache  104857600          all                                                     104857532
# RowCache          0          all  org.apache.cassandra.cache.SerializingCachePro...          0

# %%
memtables = pd.DataFrame.from_records(log.sessions[0]['status'][2]['memtables'], columns=['keyspace','column_family','ops','data'])
memtables.tail(50)
# Out:
#          keyspace                column_family      ops      data
# 11         system        schema_columnfamilies        0         0
# 12         system                    IndexInfo        0         0
# 13         system                  range_xfers        0         0
# 14         system                  peer_events        0         0
# 15         system                        hints        0         0
# 16         system            HintsColumnFamily        0         0
# 17            mca            ItemThreshold_IDX    20586   1048576
# 18            mca  ItemLocationEligibility_IDX        0         0
# 19            mca                FeatureToggle        0         0
# 20            mca      DepartmentThreshold_IDX     1980    110467
# 21            mca              ItemEligibility        0         0
# 22            mca                 AuditHistory        0         0
# 23            mca             AuditHistory_IDX        0         0
# 24            mca            FeatureToggle_IDX        0         0
# 25            mca          DepartmentThreshold     3168    142840
# 26            mca             FileLoadData_IDX       14      9356
# 27            mca                ItemThreshold    54896   1048576
# 28            mca      ItemLocationEligibility        0         0
# 29            mca          ItemEligibility_IDX        0         0
# 30            mca      LocationEligibility_IDX       20      7064
# 31            mca                 FileLoadData       42     15634
# 32            mca          LocationEligibility       70     18160
# 33     dse_system                 job_trackers        0         0
# 34    cfs_archive                      cleanup        0         0
# 35    cfs_archive                        inode        0         0
# 36    cfs_archive                      sblocks        0         0
# 37    cfs_archive                        rules        0         0
# 38            cfs                      sblocks        0         0
# 39            cfs                        inode        0         0
# 40            cfs                        rules        0         0
# 41            cfs                      cleanup        0         0
# 42            esv                    inventory        0         0
# 43            esv               barcodeMapping        0         0
# 44            esv        retailProductLocation        0         0
# 45            esv                  jobtracking        0         0
# 46            esv                retailProduct        0         0
# 47    system_auth                        users        0         0
# 48    system_auth                  credentials        0         0
# 49    system_auth                  permissions        0         0
# 50      OpsCenter                       events        0         0
# 51      OpsCenter                    rollups60  3208240  26214400
# 52      OpsCenter                     settings        0         0
# 53      OpsCenter                         pdps   967207  75497472
# 54      OpsCenter                 rollups86400     2770   1048576
# 55      OpsCenter              events_timeline        0         0
# 56      OpsCenter                   rollups300   504604   8388608
# 57      OpsCenter                  rollups7200    11079   1048576
# 58  system_traces                     sessions        0         0
# 59  system_traces                       events        0         0
# 60       dse_auth                        users        0         0

# %% [markdown]
# ## Unrecognized Messages
#
# The log parser isn't complete and probably will always be a work in progress. The goal is to parse the most useful messages first.  This report shows the number of unrecognized messages for each category/source file.  Generally when writing a new parser, I choose one of the categories at the top of the list.

# %%
unknown = pd.DataFrame.from_records(log.unknown_messages, index='date')
unknown[unknown.level == 'INFO'].source_file.value_counts()
