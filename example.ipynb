# %%
# %matplotlib inline

import pandas as pd
import cassandra
reload(cassandra)

log = cassandra.SystemLog('/Users/jblangston/Downloads/Test_Cluster-diagnostics-2014_01_06_15_19_13_UTC/nodes/opsc-2014-01-06-09-19-13-CST-10.65.131.221/logs/cassandra/system.log')
# Out:
# 	... 9 more
#
# 	... 5 more
#
# 	... 9 more
#
# java.util.concurrent.RejectedExecutionException
# java.util.concurrent.RejectedExecutionException
#
# java.util.concurrent.RejectedExecutionException

# %%
versions=pd.DataFrame.from_records(log.sessions[1]['versions'], columns=['component','version'])
versions
# Out:
#         component                       version
# 0             DSE                         3.1.4
# 1          Hadoop                       1.0.4.8
# 2            Hive                       0.9.0.1
# 3             Pig                         0.9.2
# 4            Solr                     4.3.0.1.2
# 5           Sqoop                       1.4.2.3
# 6          Mahout                           0.6
# 7        Appender                           1.1
# 8       Cassandra                      1.2.10.1
# 9      Thrift API                       19.36.0
# 10  CQL supported  2.0.0,3.0.5 (default: 3.0.5)

# %%
gc = pd.DataFrame.from_records(log.sessions[0]['garbage_collections'], 
                               columns=['date', 'collections', 'duration'], index='date')

hourly = gc.resample('H', how='sum').dropna()
hourly.plot(y='duration', logy=True)

# %%
gc['duration'].hist(bins=50)

# %%
heap_warnings = pd.DataFrame.from_records(log.sessions[0]['heap_warnings'], index='date')
heap_warnings
# Out:
#                             percent_full
# date
# 2013-12-09 13:08:55.627000      0.766896
# 2013-12-09 13:41:21.460000      0.751005
# 2013-12-11 06:23:36.933000      0.790680
# 2013-12-11 06:32:28.680000      0.778222
# 2013-12-12 10:45:20.961000      0.771217
# 2013-12-12 10:55:32.734000      0.786430
# 2013-12-13 04:37:27.090000      0.784027
# 2013-12-13 10:14:58.529000      0.773503
# 2013-12-13 16:21:04.448000      0.759328
# 2013-12-13 16:26:36.765000      0.765987
# 2013-12-13 16:56:30.835000      0.783556
# 2013-12-13 19:33:05.745000      0.767658
# 2013-12-13 19:33:24.524000      0.789572

# %%
compactions = pd.DataFrame.from_records(log.sessions[0]['compactions'],index='begin_date')
compactions.describe()
#compactions['percent_of_original'].hist(bins=50)
#compactions.sort('unique_rows').tail()
#compactions['rate'].plot()
#compactions['rate'].resample('15Min', how='count').plot()
# Out:
#              duration   input_bytes  output_bytes  percent_of_original  \
# count     6894.000000  6.894000e+03  6.894000e+03          6894.000000
# mean     30627.632144  5.781562e+07  5.600845e+07           101.386713
# std     225414.699089  3.446969e+08  2.564950e+08             4.086171
# min          5.000000  6.250000e+02  2.660000e+02            39.000000
# 25%       7544.500000  1.570305e+07  1.594695e+07           100.000000
# 50%      12812.500000  2.960630e+07  3.011574e+07           101.000000
# 75%      18701.500000  4.491040e+07  4.575721e+07           102.000000
# max    9451183.000000  1.351363e+10  9.014415e+09           123.000000
#
#               rate  sstable_count     total_rows    unique_rows
# count  6894.000000    6894.000000    6894.000000    6894.000000
# mean      2.326579       3.997534     795.646359     722.663621
# std       0.683598       0.073224   12387.582495   12332.735111
# min       0.050735       2.000000       4.000000       1.000000
# ...

# %%
flushes = pd.DataFrame.from_records(log.sessions[0]['flushes'],index='begin_date')
#flushes['file_size'].hist(bins=50)
#flushes.describe()
flushes['filename'].resample('4H', how='count').plot()

# %%
log.sessions[0]['errors']
# Out:
# [{'caused_by': [{'exception': 'java.net.SocketException',
#     'exception_message': 'Connection reset',
#     'stack_trace': [{'class': 'SocketInputStream',
#       'method': 'read',
#       'package': 'java',
#       'source_file': 'SocketInputStream.java',
#       'source_lineno': 168},
#      {'class': 'BufferedInputStream',
#       'method': 'fill',
#       'package': 'java',
#       'source_file': 'BufferedInputStream.java',
#       'source_lineno': 218},
#      {'class': 'BufferedInputStream',
#       'method': 'read1',
#       'package': 'java',
#       'source_file': 'BufferedInputStream.java',
#       'source_lineno': 258},
#      {'class': 'BufferedInputStream',
#       'method': 'read',
#       'package': 'java',
#       'source_file': 'BufferedInputStream.java',
#       'source_lineno': 317},
#      {'class': 'TIOStreamTransport',
#       'method': 'read',
#       'package': 'org.apache.thrift',
#       'source_file': 'TIOStreamTransport.java',
# ...

# %%
log.sessions[1]['environment']
# Out:
# {'classpath': ['',
#   '/usr/share/dse/dse.jar',
#   '/usr/share/dse/common/commons-codec-1.6.jar',
#   '/usr/share/dse/common/commons-io-2.4.jar',
#   '/usr/share/dse/common/guava-13.0.1.jar',
#   '/usr/share/dse/common/jbcrypt-0.3m.jar',
#   '/usr/share/dse/common/journalio-1.4.jar',
#   '/usr/share/dse/common/log4j-1.2.17.jar',
#   '/usr/share/dse/common/slf4j-api-1.7.2.jar',
#   '/usr/share/dse/common/slf4j-log4j12-1.7.2.jar',
#   '/etc/dse',
#   '/usr/share/java/jna.jar',
#   '/etc/dse/cassandra',
#   '/usr/share/dse/cassandra/tools/lib/stress.jar',
#   '/usr/share/dse/cassandra/lib/antlr-2.7.7.jar',
#   '/usr/share/dse/cassandra/lib/antlr-3.2.jar',
#   '/usr/share/dse/cassandra/lib/antlr-runtime-3.2.jar',
#   '/usr/share/dse/cassandra/lib/avro-1.4.0-cassandra-1.jar',
#   '/usr/share/dse/cassandra/lib/cassandra-all-1.2.10.1.jar',
#   '/usr/share/dse/cassandra/lib/cassandra-clientutil-1.2.10.1.jar',
#   '/usr/share/dse/cassandra/lib/cassandra-thrift-1.2.10.1.jar',
# ...

# %%
lines = pd.DataFrame.from_records(log.unrecognized, index='date')
lines.source_file.value_counts()
# Out:
# AntiEntropyService.java             9439
# SSTableReader.java                  6060
# CompactionController.java           3198
# StatusLogger.java                   1870
# ColumnFamilyStore.java               644
# StreamOut.java                       523
# CommitLogReplayer.java               328
# StreamingRepairTask.java             305
# AutoSavingCache.java                 265
# StreamOutSession.java                214
# Memtable.java                        200
# Gossiper.java                        108
# StorageService.java                  102
# CassandraDaemon.java                  55
# DatabaseDescriptor.java               42
# HintedHandOffManager.java             27
# CacheService.java                     24
# AuditLoggerPlugin.java                15
# DseConfig.java                        12
# CommitLog.java                        10
# DseDaemon.java                         9
# Server.java                            9
# ThriftServer.java                      9
# ...

# %%
lines[lines.source_file == 'AntiEntropyService.java']['message'].head()
# Out:
# date
# 2014-01-03 10:03:13.743000    [repair #8c2eb230-7490-11e3-99e8-1598aa1f9e07]...
# 2014-01-03 10:03:14.376000    [repair #8d237270-7490-11e3-99e8-1598aa1f9e07]...
# 2014-01-03 10:03:14.755000    [repair #8d607b70-7490-11e3-99e8-1598aa1f9e07]...
# 2014-01-03 10:03:14.826000    [repair #8d6c1430-7490-11e3-99e8-1598aa1f9e07]...
# 2014-01-03 10:03:14.894000    [repair #8d7710b0-7490-11e3-99e8-1598aa1f9e07]...
# Name: message, dtype: object
